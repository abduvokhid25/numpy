# %% [markdown]
# <a href="https://colab.research.google.com/github/abduvokhid25/numpy/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
mydataset = {
    'cars': ["Mers", "Bmw", "Ford", "Audi", "Lexus", "Toyota"],
    'counts': [3, 4, 6, 4, 5, 6]
}

df = pd.DataFrame(mydataset)
print(df)
# Out:
#      cars  counts
# 0    Mers       3
# 1     Bmw       4
# 2    Ford       6
# 3    Audi       4
# 4   Lexus       5
# 5  Toyota       6

# %%
df.head() #default 5 raws
# Out:
#     cars  counts
# 0   Mers       3
# 1    Bmw       4
# 2   Ford       6
# 3   Audi       4
# 4  Lexus       5

# %%
df.tail() # oxiridan 5 ta qator
# Out:
#      cars  counts
# 1     Bmw       4
# 2    Ford       6
# 3    Audi       4
# 4   Lexus       5
# 5  Toyota       6

# %%
df.shape # tuzilishini olib beradi
# Out:
# (6, 2)

# %%
df.columns # typeni korsatadi
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.types

# %%
df.describe(include = "all") # numerical column only
# Out:
#         cars    counts
# count      6  6.000000
# unique     6       NaN
# top     Mers       NaN
# freq       1       NaN
# mean     NaN  4.666667
# std      NaN  1.211060
# min      NaN  3.000000
# 25%      NaN  4.000000
# 50%      NaN  4.500000
# 75%      NaN  5.750000
# max      NaN  6.000000

# %%
df.iloc[-1]
# Out:
# cars      Toyota
# counts         6
# Name: 5, dtype: object

# %%
df[df["counts"] > 3]
# Out:
#      cars  counts
# 1     Bmw       4
# 2    Ford       6
# 3    Audi       4
# 4   Lexus       5
# 5  Toyota       6

# %%
#df.mean(numeric_only=True)
df["counts"].mean()
# Out:
# np.float64(4.666666666666667)

# %%
df.sum()
# Out:
# cars      MersBmwFordAudiLexusToyota
# counts                            28
# dtype: object

# %%
df.min()
# Out:
# cars      Audi
# counts       3
# dtype: object

# %%
df.max()
# Out:
# cars      Toyota
# counts         6
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    4.5
# dtype: float64

# %%
df.count()
# Out:
# cars      6
# counts    6
# dtype: int64

# %%
import pandas as pd

mydataset = {
    'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", "BMW"],
    'counts': [3, 7, 2, None, 1, 9, None]
}

df_missing = pd.DataFrame(mydataset)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 3    Tesla     NaN
# 4  Ferrari     1.0
# 5     Ford     9.0
# 6      BMW     NaN

# %%
df_missing.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2319/1925103766.py in <cell line: 0>()
# ----> 1 df_missing.isnull().sum()
#
# NameError: name 'df_missing' is not defined

# %%
df_missing.dropna(how="all")
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 3    Tesla     NaN
# 4  Ferrari     1.0
# 5     Ford     9.0
# 6      BMW     NaN

# %%
df_missing.dropna(axis=1)
# Out:
#       cars
# 0      BMW
# 1    Volvo
# 2     Ford
# 3    Tesla
# 4  Ferrari
# 5     Ford
# 6      BMW

# %%
df_missing.dropna(subset=['cars'])
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 3    Tesla     NaN
# 4  Ferrari     1.0
# 5     Ford     9.0
# 6      BMW     NaN

# %%
df_missing.fillna("unknown")
# Out:
#       cars   counts
# 0      BMW      3.0
# 1    Volvo      7.0
# 2     Ford      2.0
# 3    Tesla  unknown
# 4  Ferrari      1.0
# 5     Ford      9.0
# 6      BMW  unknown

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.to_excel("output.xlsx")

# %%
cars = pd.Series(["mers", "bmw", "tesla"])
print(cars)
# Out:
# 0     mers
# 1      bmw
# 2    tesla
# dtype: object

# %%
cars_series =df_missing['cars']
print (cars_series)
# Out:
# 0        BMW
# 1      Volvo
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5       Ford
# 6        BMW
# Name: cars, dtype: object
